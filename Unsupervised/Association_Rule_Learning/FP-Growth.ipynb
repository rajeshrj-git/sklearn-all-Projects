# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\rajes\Downloads\groceries.csv", header=None, on_bad_lines='skip')
data
# Out:
#                         0                         1                    2  \
# 0            citrus fruit       semi-finished bread            margarine
# 1          tropical fruit                    yogurt               coffee
# 2              whole milk                       NaN                  NaN
# 3               pip fruit                    yogurt         cream cheese
# 4        other vegetables                whole milk       condensed milk
# ...                   ...                       ...                  ...
# 6101               yogurt  long life bakery product                  NaN
# 6102                 pork         frozen vegetables               pastry
# 6103            ice cream  long life bakery product  specialty chocolate
# 6104    cooking chocolate                       NaN                  NaN
# 6105  semi-finished bread             bottled water                 soda
#
#                              3
# 0                  ready soups
# 1                          NaN
# 2                          NaN
# 3                 meat spreads
# 4     long life bakery product
# ...                        ...
# 6101                       NaN
# 6102                       NaN
# 6103             specialty bar
# 6104                       NaN
# 6105              bottled beer
#
# [6106 rows x 4 columns]

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from mlxtend.frequent_patterns import fpgrowth, association_rules
from mlxtend.preprocessing import TransactionEncoder




imputer = SimpleImputer(strategy='most_frequent')
data_imputed = imputer.fit_transform(data)
data_imputed = pd.DataFrame(data_imputed)

transactions = data_imputed.values.tolist()

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(df, min_support=0.2, use_colnames=True) 

rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

rules_sorted = rules.sort_values(by='lift', ascending=False)


# print(rules_sorted)

pd.DataFrame(rules_sorted)
# Out:
#                     antecedents                  consequents  \
# 8   (shopping bags, rolls/buns)                       (soda)
# 9                        (soda)  (shopping bags, rolls/buns)
# 11                 (rolls/buns)        (soda, shopping bags)
# 6         (soda, shopping bags)                 (rolls/buns)
# 4                        (soda)                 (rolls/buns)
# 5                  (rolls/buns)                       (soda)
# 7            (soda, rolls/buns)              (shopping bags)
# 10              (shopping bags)           (soda, rolls/buns)
# 0                        (soda)              (shopping bags)
# 1               (shopping bags)                       (soda)
# 2               (shopping bags)                 (rolls/buns)
# 3                  (rolls/buns)              (shopping bags)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 8             0.434163            0.687848  0.399279    0.919653  1.337000
# 9             0.687848            0.434163  0.399279    0.580476  1.337000
# 11            0.461841            0.660498  0.399279    0.864539  1.308920
# 6             0.660498            0.461841  0.399279    0.604513  1.308920
# 4             0.687848            0.461841  0.405830    0.590000  1.277496
# 5             0.461841            0.687848  0.405830    0.878723  1.277496
# 7             0.405830            0.853750  0.399279    0.983858  1.152395
# 10            0.853750            0.405830  0.399279    0.467677  1.152395
# 0             0.687848            0.853750  0.660498    0.960238  1.124729
# 1             0.853750            0.687848  0.660498    0.773643  1.124729
# 2             0.853750            0.461841  0.434163    0.508536  1.101107
# 3             0.461841            0.853750  0.434163    0.940071  1.101107
#
#     leverage  conviction  zhangs_metric
# 8   0.100641    3.885046       0.445459
# 9   0.100641    1.348760       0.807482
# 11  0.094235    2.506272       0.438553
# 6   0.094235    1.360750       0.695169
# 4   0.088154    1.312583       0.695876
# 5   0.088154    2.573885       0.403633
# 7   0.052802    9.060162       0.222566
# 10  0.052802    1.116183       0.904223
# 0   0.073247    3.678133       0.355267
# 1   0.073247    1.379024       0.758273
# 2   0.039866    1.095013       0.627854
# 3   0.039866    2.440378       0.170625
